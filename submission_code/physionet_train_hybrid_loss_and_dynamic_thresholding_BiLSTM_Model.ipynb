# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
import numpy as np
import os
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.callbacks import ModelCheckpoint
from sklearn.preprocessing import OneHotEncoder
import scipy
from scipy.io import loadmat
from scipy.signal import butter, filtfilt, iirnotch
from biosppy.signals import ecg
import ecg_plot
import scipy.io
import matplotlib.pyplot as plt
from model_utils_1d_BiLSTM import ecg_model
from _preprocess_utils_2d import *
import pickle
import seaborn as sns
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, auc
from tensorflow.keras import backend as K
from tensorflow.keras.saving import register_keras_serializable

# %% [markdown]
# Ensuring GPU support and set growth

# %%
# Get all visible GPUs
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    try:

        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(f"{len(gpus)} physical GPU(s), {len(logical_gpus)} logical GPU(s) configured.")

    except RuntimeError as e:
        print(e)
else:
    print("No GPU detected.")
# Out:
# 1 physical GPU(s), 1 logical GPU(s) configured.
# I0000 00:00:1752367088.690153    2681 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9558 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
# Set memory growth for all GPUs
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ### Data Generator

# %%
root_path = '/mnt/c/Users/hbala/Desktop/Chagas_Physionet2025/output'

# %%
with open('all_train_paths.pkl', 'rb') as f:
    train_paths = pickle.load(f)

train_paths = [os.path.join(root_path, path) for path in train_paths]
 
with open('all_val_paths.pkl', 'rb') as f:
    val_paths = pickle.load(f)
    
val_paths = [os.path.join(root_path, path) for path in val_paths]

# %%
train_ds = tf_dataloader(train_paths, batch_size=256, shuffle=True)
val_ds = tf_dataloader(val_paths, batch_size=256, shuffle=False)

# %%
model = ecg_model()

# with open('class_weights.pkl', 'rb') as f:
#     class_weights = pickle.load(f)
    
model.summary()
# Out:
# Model: "ECG_ConvAttn_LSTM"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ ecg12 (InputLayer)  │ (None, 4096, 12)  │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_conv3       │ (None, 4096, 6)   │        222 │ ecg12[0][0]       │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_conv5       │ (None, 4096, 6)   │        366 │ ecg12[0][0]       │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_conv7       │ (None, 4096, 6)   │        510 │ ecg12[0][0]       │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_concat1     │ (None, 4096, 12)  │          0 │ enc_b11_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b11_conv5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_concat2     │ (None, 4096, 12)  │          0 │ enc_b11_conv5[0]… │
# │ (Concatenate)       │                   │            │ enc_b11_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_concat3     │ (None, 4096, 12)  │          0 │ enc_b11_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b11_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_conv35      │ (None, 4096, 6)   │         78 │ enc_b11_concat1[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_conv57      │ (None, 4096, 6)   │         78 │ enc_b11_concat2[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_conv37      │ (None, 4096, 6)   │         78 │ enc_b11_concat3[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_concat      │ (None, 4096, 18)  │          0 │ enc_b11_conv35[0… │
# │ (Concatenate)       │                   │            │ enc_b11_conv57[0… │
# │                     │                   │            │ enc_b11_conv37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b11_finconv     │ (None, 4096, 6)   │        114 │ enc_b11_concat[0… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_conv3       │ (None, 4096, 6)   │        114 │ enc_b11_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_conv5       │ (None, 4096, 6)   │        186 │ enc_b11_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_conv7       │ (None, 4096, 6)   │        258 │ enc_b11_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_concat1     │ (None, 4096, 12)  │          0 │ enc_b12_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b12_conv5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_concat2     │ (None, 4096, 12)  │          0 │ enc_b12_conv5[0]… │
# │ (Concatenate)       │                   │            │ enc_b12_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_concat3     │ (None, 4096, 12)  │          0 │ enc_b12_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b12_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_conv35      │ (None, 4096, 6)   │         78 │ enc_b12_concat1[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_conv57      │ (None, 4096, 6)   │         78 │ enc_b12_concat2[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_conv37      │ (None, 4096, 6)   │         78 │ enc_b12_concat3[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_concat      │ (None, 4096, 18)  │          0 │ enc_b12_conv35[0… │
# │ (Concatenate)       │                   │            │ enc_b12_conv57[0… │
# │                     │                   │            │ enc_b12_conv37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b12_finconv     │ (None, 4096, 6)   │        114 │ enc_b12_concat[0… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d       │ (None, 2048, 6)   │          0 │ enc_b12_finconv[… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalization │ (None, 2048, 6)   │         12 │ max_pooling1d[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 2048, 6)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_conv3       │ (None, 2048, 3)   │         57 │ activation[0][0]  │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_conv5       │ (None, 2048, 3)   │         93 │ activation[0][0]  │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_conv7       │ (None, 2048, 3)   │        129 │ activation[0][0]  │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_concat1     │ (None, 2048, 6)   │          0 │ enc_b21_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b21_conv5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_concat2     │ (None, 2048, 6)   │          0 │ enc_b21_conv5[0]… │
# │ (Concatenate)       │                   │            │ enc_b21_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_concat3     │ (None, 2048, 6)   │          0 │ enc_b21_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b21_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_conv35      │ (None, 2048, 3)   │         21 │ enc_b21_concat1[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_conv57      │ (None, 2048, 3)   │         21 │ enc_b21_concat2[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_conv37      │ (None, 2048, 3)   │         21 │ enc_b21_concat3[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_concat      │ (None, 2048, 9)   │          0 │ enc_b21_conv35[0… │
# │ (Concatenate)       │                   │            │ enc_b21_conv57[0… │
# │                     │                   │            │ enc_b21_conv37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b21_finconv     │ (None, 2048, 3)   │         30 │ enc_b21_concat[0… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_conv3       │ (None, 2048, 3)   │         30 │ enc_b21_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_conv5       │ (None, 2048, 3)   │         48 │ enc_b21_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_conv7       │ (None, 2048, 3)   │         66 │ enc_b21_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_concat1     │ (None, 2048, 6)   │          0 │ enc_b22_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b22_conv5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_concat2     │ (None, 2048, 6)   │          0 │ enc_b22_conv5[0]… │
# │ (Concatenate)       │                   │            │ enc_b22_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_concat3     │ (None, 2048, 6)   │          0 │ enc_b22_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b22_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_conv35      │ (None, 2048, 3)   │         21 │ enc_b22_concat1[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_conv57      │ (None, 2048, 3)   │         21 │ enc_b22_concat2[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_conv37      │ (None, 2048, 3)   │         21 │ enc_b22_concat3[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_concat      │ (None, 2048, 9)   │          0 │ enc_b22_conv35[0… │
# │ (Concatenate)       │                   │            │ enc_b22_conv57[0… │
# │                     │                   │            │ enc_b22_conv37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b22_finconv     │ (None, 2048, 3)   │         30 │ enc_b22_concat[0… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_1     │ (None, 1024, 3)   │          0 │ enc_b22_finconv[… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 1024, 3)   │          6 │ max_pooling1d_1[… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 1024, 3)   │          0 │ layer_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_conv3       │ (None, 1024, 1)   │         10 │ activation_1[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_conv5       │ (None, 1024, 1)   │         16 │ activation_1[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_conv7       │ (None, 1024, 1)   │         22 │ activation_1[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_concat1     │ (None, 1024, 2)   │          0 │ enc_b31_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b31_conv5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_concat2     │ (None, 1024, 2)   │          0 │ enc_b31_conv5[0]… │
# │ (Concatenate)       │                   │            │ enc_b31_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_concat3     │ (None, 1024, 2)   │          0 │ enc_b31_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b31_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_conv35      │ (None, 1024, 1)   │          3 │ enc_b31_concat1[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_conv57      │ (None, 1024, 1)   │          3 │ enc_b31_concat2[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_conv37      │ (None, 1024, 1)   │          3 │ enc_b31_concat3[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_concat      │ (None, 1024, 3)   │          0 │ enc_b31_conv35[0… │
# │ (Concatenate)       │                   │            │ enc_b31_conv57[0… │
# │                     │                   │            │ enc_b31_conv37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b31_finconv     │ (None, 1024, 1)   │          4 │ enc_b31_concat[0… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_conv3       │ (None, 1024, 1)   │          4 │ enc_b31_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_conv5       │ (None, 1024, 1)   │          6 │ enc_b31_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_conv7       │ (None, 1024, 1)   │          8 │ enc_b31_finconv[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_concat1     │ (None, 1024, 2)   │          0 │ enc_b32_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b32_conv5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_concat2     │ (None, 1024, 2)   │          0 │ enc_b32_conv5[0]… │
# │ (Concatenate)       │                   │            │ enc_b32_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_concat3     │ (None, 1024, 2)   │          0 │ enc_b32_conv3[0]… │
# │ (Concatenate)       │                   │            │ enc_b32_conv7[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_conv35      │ (None, 1024, 1)   │          3 │ enc_b32_concat1[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_conv57      │ (None, 1024, 1)   │          3 │ enc_b32_concat2[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_conv37      │ (None, 1024, 1)   │          3 │ enc_b32_concat3[… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_concat      │ (None, 1024, 3)   │          0 │ enc_b32_conv35[0… │
# │ (Concatenate)       │                   │            │ enc_b32_conv57[0… │
# │                     │                   │            │ enc_b32_conv37[0… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ enc_b32_finconv     │ (None, 1024, 1)   │          4 │ enc_b32_concat[0… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling1d_2     │ (None, 512, 1)    │          0 │ enc_b32_finconv[… │
# │ (MaxPooling1D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mhsa                │ (None, 512, 1)    │        449 │ max_pooling1d_2[… │
# │ (MultiHeadAttentio… │                   │            │ max_pooling1d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ bilstm              │ (None, 128)       │     33,792 │ mhsa[0][0]        │
# │ (Bidirectional)     │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │     16,512 │ bilstm[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 16)        │      1,040 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 16)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 8)         │        136 │ dropout_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ out_prob (Dense)    │ (None, 1)         │          9 │ dense_3[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 63,265 (247.13 KB)
#  Trainable params: 63,265 (247.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Defining Hybrid Loss Functions

# %%
@register_keras_serializable()
def focal_loss(gamma: float = 2.0):
    """Focal Loss (Lin et al.) for binary problems with sigmoid output."""
    def _loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        bce = K.binary_crossentropy(y_true, y_pred, from_logits=False)          # already mean-reduced per-sample
        p_t = tf.clip_by_value(y_true * y_pred + (1-y_true)*(1-y_pred), 1e-7, 1-1e-7)
        focal = K.pow(1.0 - p_t, gamma) * bce
        return focal
    return _loss

@register_keras_serializable()
class AUCMarginLoss(tf.keras.losses.Loss):
    def __init__(self, margin: float = 1.0, name="auc_margin"):
        super().__init__(name=name)
        self.margin = margin

    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        pos = tf.boolean_mask(y_pred, tf.equal(y_true, 1))
        neg = tf.boolean_mask(y_pred, tf.equal(y_true, 0))

        # Compute the loss only if we have BOTH positives and negatives
        def compute_pairwise():
            pairwise = tf.maximum(
                0.0,
                self.margin - tf.expand_dims(pos, 1) + tf.expand_dims(neg, 0)
            )
            return tf.reduce_mean(pairwise)

        no_pairs = tf.logical_or(tf.equal(tf.size(pos), 0),
                                 tf.equal(tf.size(neg), 0))
        return tf.cond(no_pairs,
                       lambda: tf.constant(0.0, dtype=tf.float32),
                       compute_pairwise)

# %%
focal = focal_loss(gamma=2.0)
auc_margin = AUCMarginLoss(margin=1.0)

@register_keras_serializable()
def hybrid_loss(y_true, y_pred):
    return 0.7 * focal(y_true, y_pred) + 0.3 * auc_margin(y_true, y_pred)

# %% [markdown]
# #### Dynamic Thresholding based on auc_roc curves

# %%
@register_keras_serializable()
class DynamicThreshold(tf.keras.callbacks.Callback):
    def __init__(self, val_ds, threshold_var):
        super().__init__()
        self.val_ds = val_ds
        self.threshold_var = threshold_var

    @tf.function  # speeds up large val sets
    def _collect(self, x):
        return self.model(x, training=False)

    def on_epoch_end(self, epoch, logs=None):
        y_true, y_score = [], []
        for x, y in self.val_ds:
            y_score.append(self._collect(x))
            y_true.append(tf.cast(y, tf.float32))

        y_true  = tf.concat(y_true,  axis=0).numpy().ravel()
        y_score = tf.concat(y_score, axis=0).numpy().ravel()

        fpr, tpr, thresh = roc_curve(y_true, y_score)
        finite = np.isfinite(thresh)         # skip the +inf sentinel
        best = np.argmax(tpr[finite] - fpr[finite])

        best_thr = float(thresh[finite][best])
        self.threshold_var.assign(best_thr)

        if logs is not None:
            logs["val_best_threshold"] = best_thr

# %%
@register_keras_serializable()
class TopKTPR(tf.keras.metrics.Metric):
    def __init__(self, k_fraction=0.05, name="tpr_at_top5", **kw):
        super().__init__(name=name, **kw)
        self.k_fraction = float(k_fraction)
        self.tp = self.add_weight(name="tp", initializer="zeros")
        self.p  = self.add_weight(name="p",  initializer="zeros")

    def update_state(self, y_true, y_pred, sample_weight=None):
        # Flatten (works for any output shape)
        y_true = tf.reshape(tf.cast(y_true, tf.float32), [-1])
        y_pred = tf.reshape(tf.cast(y_pred, tf.float32), [-1])

        n = tf.cast(tf.size(y_pred), tf.float32)
        k = tf.cast(tf.math.maximum(1.0, tf.math.ceil(n * self.k_fraction)), tf.int32)

        # ---- efficient mask: no full scatter for large n ----
        topk_idx = tf.math.top_k(y_pred, k=k, sorted=False).indices
        topk_true = tf.gather(y_true, topk_idx)

        self.tp.assign_add(tf.reduce_sum(topk_true))
        self.p.assign_add(tf.reduce_sum(y_true))

    def result(self):
        return self.tp / (self.p + tf.keras.backend.epsilon())

    def reset_states(self):
        self.tp.assign(0.0)
        self.p.assign(0.0)

# %%
threshold_var = tf.Variable(0.5, dtype=tf.float32, trainable=False, name="dyn_thresh")

@register_keras_serializable()
def f1_metric(threshold_var):
    def _f1(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred_bin = tf.cast(tf.greater_equal(y_pred, threshold_var), tf.float32)

        tp = tf.reduce_sum(y_true * y_pred_bin)
        fn = tf.reduce_sum(y_true * (1 - y_pred_bin))
        fp = tf.reduce_sum((1 - y_true) * y_pred_bin)

        precision = tp / (tp + fp + K.epsilon())
        recall    = tp / (tp + fn + K.epsilon())
        return 2 * precision * recall / (precision + recall + K.epsilon())
    return _f1

model.compile(
    optimizer='adam',
    loss=focal_loss(gamma=2.0),  # Use focal loss
    metrics=['accuracy',
             tf.keras.metrics.AUC(name="auc"),
             f1_metric(threshold_var),
             TopKTPR(k_fraction=0.05)]
)


model_checkpoint = ModelCheckpoint(
    'phy_2025_best_weight_model_filtered_paths_2d_focal_loss_7_13_25.keras',
    monitor='val_tpr_at_top5',
    save_best_only=True,
    mode='max'
)

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_tpr_at_top5',
    patience=10,
    verbose=1,
    mode='max',
    restore_best_weights=True
)

# %%
class_weights = {0: 1.0, 1: 25.0}

# %%
dynamic_thresh_cb = DynamicThreshold(val_ds, threshold_var)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[model_checkpoint, early_stopping, dynamic_thresh_cb],
    verbose=1
)
# Out:
# Epoch 1/100
# I0000 00:00:1752367159.723655    2866 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5595s 5s/step - _f1: 9.9701e-05 - accuracy: 0.9769 - auc: 0.4967 - loss: 0.0416 - tpr_at_top5: 0.0491 - val__f1: 0.0000e+00 - val_accuracy: 0.9769 - val_auc: 0.5000 - val_loss: 0.0326 - val_tpr_at_top5: 0.2433 - val_best_threshold: 0.2084
# Epoch 2/100
# 2025-07-12 21:12:23.512741: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5562s 5s/step - _f1: 0.0396 - accuracy: 0.9780 - auc: 0.6813 - loss: 0.0294 - tpr_at_top5: 0.1928 - val__f1: 0.0379 - val_accuracy: 0.9769 - val_auc: 0.7625 - val_loss: 0.0294 - val_tpr_at_top5: 0.2641 - val_best_threshold: 0.1874
# Epoch 3/100
# 2025-07-12 22:45:05.590702: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5574s 5s/step - _f1: 0.0405 - accuracy: 0.9782 - auc: 0.7563 - loss: 0.0275 - tpr_at_top5: 0.2901 - val__f1: 0.0443 - val_accuracy: 0.9769 - val_auc: 0.7849 - val_loss: 0.0292 - val_tpr_at_top5: 0.3039 - val_best_threshold: 0.2258
# Epoch 4/100
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5602s 5s/step - _f1: 0.0380 - accuracy: 0.9775 - auc: 0.7713 - loss: 0.0277 - tpr_at_top5: 0.3055 - val__f1: 0.0409 - val_accuracy: 0.9769 - val_auc: 0.7927 - val_loss: 0.0284 - val_tpr_at_top5: 0.3294 - val_best_threshold: 0.2215
# Epoch 5/100
# 2025-07-13 01:51:21.267714: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5518s 5s/step - _f1: 0.0370 - accuracy: 0.9781 - auc: 0.7775 - loss: 0.0268 - tpr_at_top5: 0.3320 - val__f1: 0.0426 - val_accuracy: 0.9769 - val_auc: 0.8047 - val_loss: 0.0290 - val_tpr_at_top5: 0.3401 - val_best_threshold: 0.2296
# Epoch 6/100
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5506s 5s/step - _f1: 0.0365 - accuracy: 0.9778 - auc: 0.7936 - loss: 0.0266 - tpr_at_top5: 0.3485 - val__f1: 0.0373 - val_accuracy: 0.9769 - val_auc: 0.8135 - val_loss: 0.0271 - val_tpr_at_top5: 0.3596 - val_best_threshold: 0.2090
# Epoch 7/100
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5511s 5s/step - _f1: 0.0381 - accuracy: 0.9781 - auc: 0.8033 - loss: 0.0258 - tpr_at_top5: 0.3673 - val__f1: 0.0421 - val_accuracy: 0.9769 - val_auc: 0.8236 - val_loss: 0.0275 - val_tpr_at_top5: 0.3715 - val_best_threshold: 0.2109
# Epoch 8/100
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5515s 5s/step - _f1: 0.0378 - accuracy: 0.9780 - auc: 0.8168 - loss: 0.0253 - tpr_at_top5: 0.3912 - val__f1: 0.0425 - val_accuracy: 0.9770 - val_auc: 0.8292 - val_loss: 0.0268 - val_tpr_at_top5: 0.3864 - val_best_threshold: 0.2143
# Epoch 9/100
# 2025-07-13 07:58:50.959464: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5513s 5s/step - _f1: 0.0379 - accuracy: 0.9780 - auc: 0.8076 - loss: 0.0258 - tpr_at_top5: 0.3686 - val__f1: 0.0423 - val_accuracy: 0.9772 - val_auc: 0.8180 - val_loss: 0.0273 - val_tpr_at_top5: 0.3484 - val_best_threshold: 0.2182
# Epoch 10/100
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5524s 5s/step - _f1: 0.0375 - accuracy: 0.9782 - auc: 0.8170 - loss: 0.0255 - tpr_at_top5: 0.3782 - val__f1: 0.0393 - val_accuracy: 0.9769 - val_auc: 0.7822 - val_loss: 0.0281 - val_tpr_at_top5: 0.3050 - val_best_threshold: 0.2013
# Epoch 11/100
# 1141/1141 ━━━━━━━━━━━━━━━━━━━━ 5581s 5s/step - _f1: 0.0398 - accuracy: 0.9778 - auc: 0.7902 - loss: 0.0266 - tpr_at_top5: 0.3429 - val__f1: 0.0423 - val_accuracy: 0.9770 - val_auc: 0.8120 - val_loss: 0.0268 - val_tpr_at_top5: 0.3466 - val_best_threshold: 0.2062
# Epoch 11: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
model.save('phy_2025_best_weight_model_filtered_paths_2d_focal_loss_7_12_25.keras')

# %%
# Load model and evaluate on validation set
loaded_model = tf.keras.models.load_model(
    'phy_2025_best_weight_model_filtered_paths_2d_focal_loss_7_12_25.keras',
    custom_objects={'focal_loss': focal_loss, 'f1_metric': f1_metric, 'TopKTPR': TopKTPR, 'DynamicThreshold': DynamicThreshold}
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 2
#       1 # Load model and evaluate on validation set
# ----> 2 loaded_model = tf.keras.models.load_model(
#       3     'phy_2025_best_weight_model_filtered_paths_2d_focal_loss_7_12_25.keras',
#       4     custom_objects={'focal_loss': focal_loss, 'f1_metric': f1_metric, 'TopKTPR': TopKTPR, 'DynamicThreshold': DynamicThreshold}
#       5 )
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/saving_api.py:189, in load_model(filepath, custom_objects, compile, safe_mode)
#     186         is_keras_zip = True
#     188 if is_keras_zip or is_keras_dir or is_hf:
# --> 189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:370, in load_model(filepath, custom_objects, compile, safe_mode)
#     365     raise ValueError(
#     366         "Invalid filename: expected a `.keras` extension. "
#     367         f"Received: filepath={filepath}"
#     368     )
#     369 with open(filepath, "rb") as f:
# --> 370     return _load_model_from_fileobj(
#     371         f, custom_objects, compile, safe_mode
#     372     )
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:447, in _load_model_from_fileobj(fileobj, custom_objects, compile, safe_mode)
#     444 with zf.open(_CONFIG_FILENAME, "r") as f:
#     445     config_json = f.read()
# --> 447 model = _model_from_config(
#     448     config_json, custom_objects, compile, safe_mode
#     449 )
#     451 all_filenames = zf.namelist()
#     452 extract_dir = None
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:436, in _model_from_config(config_json, custom_objects, compile, safe_mode)
#     434 # Construct the model from the configuration file in the archive.
#     435 with ObjectSharingScope():
# --> 436     model = deserialize_keras_object(
#     437         config_dict, custom_objects, safe_mode=safe_mode
#     438     )
#     439 return model
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:734, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     732     compile_config = config.get("compile_config", None)
#     733     if compile_config:
# --> 734         instance.compile_from_config(compile_config)
#     735         instance.compiled = True
#     737 if "shared_object_id" in config:
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/trainers/trainer.py:972, in Trainer.compile_from_config(self, config)
#     961     warnings.warn(
#     962         "`compile()` was not called as part of model loading "
#     963         "because the model's `compile()` method is custom. "
#    (...)
#     969         stacklevel=2,
#     970     )
#     971     return
# --> 972 config = serialization_lib.deserialize_keras_object(config)
#     973 self.compile(**config)
#     974 if hasattr(self, "optimizer") and self.built:
#     975     # Create optimizer variables.
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:594, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     591     raise TypeError(f"Could not parse config: {config}")
#     593 if "class_name" not in config or "config" not in config:
# --> 594     return {
#     595         key: deserialize_keras_object(
#     596             value, custom_objects=custom_objects, safe_mode=safe_mode
#     597         )
#     598         for key, value in config.items()
#     599     }
#     601 class_name = config["class_name"]
#     602 inner_config = config["config"] or {}
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:595, in <dictcomp>(.0)
#     591     raise TypeError(f"Could not parse config: {config}")
#     593 if "class_name" not in config or "config" not in config:
#     594     return {
# --> 595         key: deserialize_keras_object(
#     596             value, custom_objects=custom_objects, safe_mode=safe_mode
#     597         )
#     598         for key, value in config.items()
#     599     }
#     601 class_name = config["class_name"]
#     602 inner_config = config["config"] or {}
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:678, in deserialize_keras_object(config, custom_objects, safe_mode, **kwargs)
#     676 if class_name == "function":
#     677     fn_name = inner_config
# --> 678     return _retrieve_class_or_fn(
#     679         fn_name,
#     680         registered_name,
#     681         module,
#     682         obj_type="function",
#     683         full_config=config,
#     684         custom_objects=custom_objects,
#     685     )
#     687 # Below, handling of all classes.
#     688 # First, is it a shared object?
#     689 if "shared_object_id" in config:
#
# File ~/miniconda3/envs/physionet_env/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:810, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     803         except ModuleNotFoundError:
#     804             raise TypeError(
#     805                 f"Could not deserialize {obj_type} '{name}' because "
#     806                 f"its parent module {module} cannot be imported. "
#     807                 f"Full object config: {full_config}"
#     808             )
# --> 810 raise TypeError(
#     811     f"Could not locate {obj_type} '{name}'. "
#     812     "Make sure custom classes are decorated with "
#     813     "`@keras.saving.register_keras_serializable()`. "
#     814     f"Full object config: {full_config}"
#     815 )
#
# TypeError: Could not locate function '_loss'. Make sure custom classes are decorated with `@keras.saving.register_keras_serializable()`. Full object config: {'module': 'builtins', 'class_name': 'function', 'config': '_loss', 'registered_name': 'function'}

# %%
model.evaluate(val_ds, verbose=1)
# Out:
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 397s 1s/step - _f1: 0.0456 - accuracy: 0.9766 - auc: 0.5000 - loss: 0.0328 - tpr_at_top5: 0.2449
# [0.032561369240283966,
#  0.9769095778465271,
#  0.5,
#  0.04482297971844673,
#  0.2433234453201294]

# %%
model.load_weights('phy_2025_best_weight_model_filtered_paths_2d_focal_loss_7_12_25.keras')
model.evaluate(val_ds, verbose=1)
# Out:
# 286/286 ━━━━━━━━━━━━━━━━━━━━ 397s 1s/step - _f1: 0.0436 - accuracy: 0.9767 - auc: 0.8361 - loss: 0.0268 - tpr_at_top5: 0.3915
# [0.026778055354952812,
#  0.977019190788269,
#  0.8291621208190918,
#  0.04289998859167099,
#  0.386350154876709]

# %%
# get the best threshold from the dynamic threshold callback

# %%
best_thr = dynamic_thresh_cb.threshold_var

# %%
# Collect true labels and predicted probabilities from the test dataset.
def conufsion_matrix_plots(val_ds, model): 
    y_true = []
    y_score = []  # predicted probabilities for the positive class

    # Loop over your test dataset (e.g., val_ds)
    for batch_x, batch_y in val_ds:
        preds = model.predict(batch_x, verbose=0)
        y_score.extend(preds.ravel().tolist())
        y_true.extend(batch_y.numpy().ravel().tolist())

    y_true = np.array(y_true)
    y_score = np.array(y_score)

    # Compute ROC curve and AUC
    fpr, tpr, thresholds = roc_curve(y_true, y_score)
    roc_auc = auc(fpr, tpr)

    # Compute best threshold using the Youden index (maximizes TPR - FPR)
    youden_index = tpr - fpr
    best_index = np.argmax(youden_index)
    best_threshold = thresholds[best_index]
    print("Best threshold (Youden index):", best_threshold)

    # Apply the best threshold to get binary predictions
    y_pred = (y_score >= best_threshold).astype(np.int32)

    # Generate classification report
    report = classification_report(y_true, y_pred, target_names=["False", "True"])
    print("Classification Report:")
    print(report)

    # Compute and plot confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
                xticklabels=["False", "True"], yticklabels=["False", "True"])
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()

    # Plot the ROC curve with best threshold indicated
    plt.figure(figsize=(8, 6))
    plt.plot(fpr, tpr, color="darkorange", lw=2, label="ROC curve (area = %0.2f)" % roc_auc)
    plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--", label="Random classifier")
    plt.scatter(fpr[best_index], tpr[best_index], color="red",
                label="Best threshold = %0.2f" % best_threshold)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Receiver Operating Characteristic")
    plt.legend(loc="lower right")
    plt.show()
